# %%
from sqlalchemy.ext.automap import automap_base

Base = automap_base()

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///Chinook_Sqlite.sqlite', echo=True)

# %%
Base.prepare(engine, reflect=True)
# Out:
# 2024-01-04 08:45:14,701 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2024-01-04 08:45:14,707 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,721 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Album")
# 2024-01-04 08:45:14,722 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,726 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,727 INFO sqlalchemy.engine.Engine [raw sql] ('Album',)
# 2024-01-04 08:45:14,730 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Album")
# 2024-01-04 08:45:14,731 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,732 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,733 INFO sqlalchemy.engine.Engine [raw sql] ('Album',)
# 2024-01-04 08:45:14,735 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Artist")
# 2024-01-04 08:45:14,738 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,739 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,740 INFO sqlalchemy.engine.Engine [raw sql] ('Artist',)
# 2024-01-04 08:45:14,742 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Artist")
# 2024-01-04 08:45:14,743 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,745 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Artist")
# 2024-01-04 08:45:14,746 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,748 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,750 INFO sqlalchemy.engine.Engine [raw sql] ('Artist',)
# 2024-01-04 08:45:14,752 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Artist")
# 2024-01-04 08:45:14,753 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,754 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Artist")
# 2024-01-04 08:45:14,755 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,758 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Artist")
# 2024-01-04 08:45:14,759 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,760 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Artist")
# 2024-01-04 08:45:14,761 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,762 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,763 INFO sqlalchemy.engine.Engine [raw sql] ('Artist',)
# 2024-01-04 08:45:14,765 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Album")
# 2024-01-04 08:45:14,766 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,767 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_AlbumArtistId")
# 2024-01-04 08:45:14,768 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,769 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Album")
# 2024-01-04 08:45:14,770 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,772 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Album")
# 2024-01-04 08:45:14,773 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,775 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_AlbumArtistId")
# 2024-01-04 08:45:14,776 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,777 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Album")
# 2024-01-04 08:45:14,778 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,780 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,780 INFO sqlalchemy.engine.Engine [raw sql] ('Album',)
# 2024-01-04 08:45:14,782 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Customer")
# 2024-01-04 08:45:14,788 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,804 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,806 INFO sqlalchemy.engine.Engine [raw sql] ('Customer',)
# 2024-01-04 08:45:14,810 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Customer")
# 2024-01-04 08:45:14,813 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,815 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,821 INFO sqlalchemy.engine.Engine [raw sql] ('Customer',)
# 2024-01-04 08:45:14,826 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Employee")
# 2024-01-04 08:45:14,827 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,830 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,832 INFO sqlalchemy.engine.Engine [raw sql] ('Employee',)
# 2024-01-04 08:45:14,833 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Employee")
# 2024-01-04 08:45:14,834 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,837 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,844 INFO sqlalchemy.engine.Engine [raw sql] ('Employee',)
# 2024-01-04 08:45:14,848 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Employee")
# 2024-01-04 08:45:14,850 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,853 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_EmployeeReportsTo")
# 2024-01-04 08:45:14,854 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,857 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Employee")
# 2024-01-04 08:45:14,859 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,861 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Employee")
# 2024-01-04 08:45:14,865 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,867 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_EmployeeReportsTo")
# 2024-01-04 08:45:14,873 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,876 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Employee")
# 2024-01-04 08:45:14,877 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,880 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,881 INFO sqlalchemy.engine.Engine [raw sql] ('Employee',)
# 2024-01-04 08:45:14,883 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Customer")
# 2024-01-04 08:45:14,885 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,888 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_CustomerSupportRepId")
# 2024-01-04 08:45:14,892 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,896 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Customer")
# 2024-01-04 08:45:14,897 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,901 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Customer")
# 2024-01-04 08:45:14,902 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,903 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_CustomerSupportRepId")
# 2024-01-04 08:45:14,904 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,906 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Customer")
# 2024-01-04 08:45:14,908 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,911 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,912 INFO sqlalchemy.engine.Engine [raw sql] ('Customer',)
# 2024-01-04 08:45:14,915 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Genre")
# 2024-01-04 08:45:14,917 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,919 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,921 INFO sqlalchemy.engine.Engine [raw sql] ('Genre',)
# 2024-01-04 08:45:14,923 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Genre")
# 2024-01-04 08:45:14,925 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,926 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Genre")
# 2024-01-04 08:45:14,927 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,929 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,930 INFO sqlalchemy.engine.Engine [raw sql] ('Genre',)
# 2024-01-04 08:45:14,932 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Genre")
# 2024-01-04 08:45:14,934 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,936 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Genre")
# 2024-01-04 08:45:14,938 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,942 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Genre")
# 2024-01-04 08:45:14,943 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,946 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Genre")
# 2024-01-04 08:45:14,947 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,949 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,950 INFO sqlalchemy.engine.Engine [raw sql] ('Genre',)
# 2024-01-04 08:45:14,952 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Invoice")
# 2024-01-04 08:45:14,952 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,954 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,955 INFO sqlalchemy.engine.Engine [raw sql] ('Invoice',)
# 2024-01-04 08:45:14,957 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Invoice")
# 2024-01-04 08:45:14,959 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,960 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,961 INFO sqlalchemy.engine.Engine [raw sql] ('Invoice',)
# 2024-01-04 08:45:14,963 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Invoice")
# 2024-01-04 08:45:14,964 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,966 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceCustomerId")
# 2024-01-04 08:45:14,968 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,970 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Invoice")
# 2024-01-04 08:45:14,971 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,973 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Invoice")
# 2024-01-04 08:45:14,975 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,977 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceCustomerId")
# 2024-01-04 08:45:14,978 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,980 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Invoice")
# 2024-01-04 08:45:14,982 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,984 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,986 INFO sqlalchemy.engine.Engine [raw sql] ('Invoice',)
# 2024-01-04 08:45:14,989 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("InvoiceLine")
# 2024-01-04 08:45:14,991 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:14,994 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:14,997 INFO sqlalchemy.engine.Engine [raw sql] ('InvoiceLine',)
# 2024-01-04 08:45:14,999 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("InvoiceLine")
# 2024-01-04 08:45:15,000 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,003 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,004 INFO sqlalchemy.engine.Engine [raw sql] ('InvoiceLine',)
# 2024-01-04 08:45:15,006 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Track")
# 2024-01-04 08:45:15,007 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,010 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,011 INFO sqlalchemy.engine.Engine [raw sql] ('Track',)
# 2024-01-04 08:45:15,013 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Track")
# 2024-01-04 08:45:15,014 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,016 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,017 INFO sqlalchemy.engine.Engine [raw sql] ('Track',)
# 2024-01-04 08:45:15,019 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("MediaType")
# 2024-01-04 08:45:15,019 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,021 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,021 INFO sqlalchemy.engine.Engine [raw sql] ('MediaType',)
# 2024-01-04 08:45:15,022 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("MediaType")
# 2024-01-04 08:45:15,023 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,027 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("MediaType")
# 2024-01-04 08:45:15,028 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,030 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,032 INFO sqlalchemy.engine.Engine [raw sql] ('MediaType',)
# 2024-01-04 08:45:15,034 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("MediaType")
# 2024-01-04 08:45:15,036 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,038 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_MediaType")
# 2024-01-04 08:45:15,041 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,044 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("MediaType")
# 2024-01-04 08:45:15,046 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,048 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_MediaType")
# 2024-01-04 08:45:15,049 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,051 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,052 INFO sqlalchemy.engine.Engine [raw sql] ('MediaType',)
# 2024-01-04 08:45:15,055 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Track")
# 2024-01-04 08:45:15,056 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,057 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackMediaTypeId")
# 2024-01-04 08:45:15,059 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,061 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackGenreId")
# 2024-01-04 08:45:15,062 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,064 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackAlbumId")
# 2024-01-04 08:45:15,065 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,066 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Track")
# 2024-01-04 08:45:15,066 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,068 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Track")
# 2024-01-04 08:45:15,069 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,072 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackMediaTypeId")
# 2024-01-04 08:45:15,073 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,076 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackGenreId")
# 2024-01-04 08:45:15,077 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,080 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_TrackAlbumId")
# 2024-01-04 08:45:15,082 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,084 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Track")
# 2024-01-04 08:45:15,085 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,087 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,088 INFO sqlalchemy.engine.Engine [raw sql] ('Track',)
# 2024-01-04 08:45:15,090 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("InvoiceLine")
# 2024-01-04 08:45:15,091 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,093 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceLineTrackId")
# 2024-01-04 08:45:15,094 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,095 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceLineInvoiceId")
# 2024-01-04 08:45:15,096 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,097 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_InvoiceLine")
# 2024-01-04 08:45:15,098 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,100 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("InvoiceLine")
# 2024-01-04 08:45:15,101 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,102 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceLineTrackId")
# 2024-01-04 08:45:15,103 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,104 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_InvoiceLineInvoiceId")
# 2024-01-04 08:45:15,106 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,109 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_InvoiceLine")
# 2024-01-04 08:45:15,111 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,113 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,114 INFO sqlalchemy.engine.Engine [raw sql] ('InvoiceLine',)
# 2024-01-04 08:45:15,117 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Playlist")
# 2024-01-04 08:45:15,117 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,119 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,120 INFO sqlalchemy.engine.Engine [raw sql] ('Playlist',)
# 2024-01-04 08:45:15,122 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Playlist")
# 2024-01-04 08:45:15,125 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,127 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Playlist")
# 2024-01-04 08:45:15,129 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,131 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,132 INFO sqlalchemy.engine.Engine [raw sql] ('Playlist',)
# 2024-01-04 08:45:15,134 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Playlist")
# 2024-01-04 08:45:15,135 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,139 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Playlist")
# 2024-01-04 08:45:15,140 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,143 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Playlist")
# 2024-01-04 08:45:15,144 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,147 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_Playlist")
# 2024-01-04 08:45:15,148 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,150 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,151 INFO sqlalchemy.engine.Engine [raw sql] ('Playlist',)
# 2024-01-04 08:45:15,154 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("PlaylistTrack")
# 2024-01-04 08:45:15,155 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,158 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,159 INFO sqlalchemy.engine.Engine [raw sql] ('PlaylistTrack',)
# 2024-01-04 08:45:15,161 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("PlaylistTrack")
# 2024-01-04 08:45:15,162 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,164 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,165 INFO sqlalchemy.engine.Engine [raw sql] ('PlaylistTrack',)
# 2024-01-04 08:45:15,168 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("PlaylistTrack")
# 2024-01-04 08:45:15,169 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,171 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_PlaylistTrackTrackId")
# 2024-01-04 08:45:15,172 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,174 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_PlaylistTrack")
# 2024-01-04 08:45:15,176 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,179 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("PlaylistTrack")
# 2024-01-04 08:45:15,180 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,181 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IFK_PlaylistTrackTrackId")
# 2024-01-04 08:45:15,183 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,185 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("IPK_PlaylistTrack")
# 2024-01-04 08:45:15,186 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,188 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("sqlite_autoindex_PlaylistTrack_1")
# 2024-01-04 08:45:15,189 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-01-04 08:45:15,191 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2024-01-04 08:45:15,192 INFO sqlalchemy.engine.Engine [raw sql] ('PlaylistTrack',)

# %%
Base.classes.keys()
# Out:
# ['Album',
#  'Artist',
#  'Customer',
#  'Employee',
#  'Genre',
#  'Invoice',
#  'InvoiceLine',
#  'Track',
#  'MediaType',
#  'Playlist']

# %%
Artist = Base.classes.Artist
Album = Base.classes.Album

# %%
from sqlalchemy.orm import Session

session = Session(engine)
for artist in session.query(Artist).limit(10):
    print(artist.ArtistId, artist.Name)
# Out:
# 2024-01-04 08:45:15,388 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-04 08:45:15,392 INFO sqlalchemy.engine.Engine SELECT "Artist"."ArtistId" AS "Artist_ArtistId", "Artist"."Name" AS "Artist_Name"
# FROM "Artist"
#  LIMIT ? OFFSET ?
# 2024-01-04 08:45:15,394 INFO sqlalchemy.engine.Engine [generated in 0.00180s] (10, 0)
# 1 AC/DC
# 2 Accept
# 3 Aerosmith
# 4 Alanis Morissette
# 5 Alice In Chains
# 6 Antônio Carlos Jobim
# 7 Apocalyptica
# 8 Audioslave
# 9 BackBeat
# 10 Billy Cobham

# %%
# Example 10-4 Using the relationship between Artist and Album to print related data
artist = session.query(Artist).first()
for album in artist.album_collection:
    print('{} - {}'.format(artist.Name, album.Title))
# Out:
# 2024-01-04 08:47:14,993 INFO sqlalchemy.engine.Engine SELECT "Artist"."ArtistId" AS "Artist_ArtistId", "Artist"."Name" AS "Artist_Name"
# FROM "Artist"
#  LIMIT ? OFFSET ?
# 2024-01-04 08:47:14,994 INFO sqlalchemy.engine.Engine [cached since 119.6s ago] (1, 0)
# 2024-01-04 08:47:15,015 INFO sqlalchemy.engine.Engine SELECT "Album"."AlbumId" AS "Album_AlbumId", "Album"."Title" AS "Album_Title", "Album"."ArtistId" AS "Album_ArtistId"
# FROM "Album"
# WHERE ? = "Album"."ArtistId"
# 2024-01-04 08:47:15,017 INFO sqlalchemy.engine.Engine [generated in 0.00145s] (1,)
# AC/DC - For Those About To Rock We Salute You
# AC/DC - Let There Be Rock
